# %% [markdown]
# # 1. [RI/2025/PRELIM/P2/Q3]
# The school has been experiencing an increasing number of lost items. You are tasked to create a **Lost and Found** web application and store the data about lost items in a MongoDB database. Your app will allow the Student Affairs staff to submit a new lost item report, view existing lost items in the database, and perform a search on lost items database.

# %% [markdown]
# ## Task 1
# Write a program to:
# - create a Mongo client to connect to database `lostfoundDB`
# - use the data in `lost_items.json` to populate the collection `reports`
#
# Save your program code as
#
# ```text
# Task3_1_<name>_<index number>.py
# ```
#
# in a folder named `Task3_1_<name>_<index number>`
# <div style="text-align: right">[3]</div>

# %%
from pymongo import MongoClient
import json

client = MongoClient('localhost',27017)
database = client["lostfoundDB"]
coll = database["reports"]

with open("resources/lost_items.json") as f:
    data = json.load(f)

print(data)
coll.insert_many(data)
# Out:
# [{'item_name': 'Marker pack', 'description': 'Marker pack was left near the Computer Lab.', 'category': 'Stationery', 'date_lost': '2025-07-20', 'location': 'Computer Lab', 'recovered': False}, {'item_name': 'Smartwatch', 'description': 'Smartwatch was left near the Canteen.', 'category': 'Electronics', 'date_lost': '2025-07-28', 'location': 'Canteen', 'recovered': False}, {'item_name': 'Track pants', 'description': 'Track pants was left near the Toilet.', 'category': 'Clothing', 'date_lost': '2025-07-05', 'location': 'Toilet', 'recovered': False}, {'item_name': 'Calculator', 'description': 'Calculator was left near the Library.', 'category': 'Electronics', 'date_lost': '2025-07-13', 'location': 'Library', 'recovered': False}, {'item_name': 'Tablet', 'description': 'Tablet was left near the Library.', 'category': 'Electronics', 'date_lost': '2025-07-11', 'location': 'Library', 'recovered': False}, {'item_name': 'Chemistry notes', 'description': 'Chemistry notes was left near the Field.', 'category': 'Books', 'date_lost': '2025-07-24', 'location': 'Field', 'recovered': False}, {'item_name': 'Track pants', 'description': 'Track pants was left near the Field.', 'category': 'Clothing', 'date_lost': '2025-07-21', 'location': 'Field', 'recovered': False}, {'item_name': 'School tie', 'description': 'School tie was left near the Staff Room.', 'category': 'Clothing', 'date_lost': '2025-07-02', 'location': 'Staff Room', 'recovered': False}, {'item_name': 'Tablet', 'description': 'Tablet was left near the Classroom Block A.', 'category': 'Electronics', 'date_lost': '2025-07-03', 'location': 'Classroom Block A', 'recovered': False}, {'item_name': 'Chemistry notes', 'description': 'Chemistry notes was left near the Field.', 'category': 'Books', 'date_lost': '2025-07-14', 'location': 'Field', 'recovered': False}, {'item_name': 'Pen box', 'description': 'Pen box was left near the Field.', 'category': 'Stationery', 'date_lost': '2025-07-13', 'location': 'Field', 'recovered': False}, {'item_name': 'Hairband', 'description': 'Hairband was left near the Hall.', 'category': 'Accessories', 'date_lost': '2025-07-30', 'location': 'Hall', 'recovered': False}, {'item_name': 'Black hoodie', 'description': 'Black hoodie was left near the Canteen.', 'category': 'Clothing', 'date_lost': '2025-07-23', 'location': 'Canteen', 'recovered': False}, {'item_name': 'Pencil case', 'description': 'Pencil case was left near the Canteen.', 'category': 'Stationery', 'date_lost': '2025-07-17', 'location': 'Canteen', 'recovered': False}, {'item_name': 'Wireless earphones', 'description': 'Wireless earphones was left near the Classroom Block A.', 'category': 'Electronics', 'date_lost': '2025-07-19', 'location': 'Classroom Block A', 'recovered': False}, {'item_name': 'Wallet', 'description': 'Wallet was left near the Field.', 'category': 'Accessories', 'date_lost': '2025-07-31', 'location': 'Field', 'recovered': False}, {'item_name': 'Scientific calculator', 'description': 'Scientific calculator was left near the Library.', 'category': 'Stationery', 'date_lost': '2025-07-02', 'location': 'Library', 'recovered': False}, {'item_name': 'Blue PE T-shirt', 'description': 'Blue PE T-shirt was left near the Staff Room.', 'category': 'Clothing', 'date_lost': '2025-07-15', 'location': 'Staff Room', 'recovered': False}, {'item_name': 'Scientific calculator', 'description': 'Scientific calculator was left near the Staff Room.', 'category': 'Stationery', 'date_lost': '2025-07-31', 'location': 'Staff Room', 'recovered': False}, {'item_name': 'Track pants', 'description': 'Track pants was left near the Computer Lab.', 'category': 'Clothing', 'date_lost': '2025-07-03', 'location': 'Computer Lab', 'recovered': False}]
# InsertManyResult([ObjectId('6a430237a0efda162ec66a43'), ObjectId('6a430237a0efda162ec66a44'), ObjectId('6a430237a0efda162ec66a45'), ObjectId('6a430237a0efda162ec66a46'), ObjectId('6a430237a0efda162ec66a47'), ObjectId('6a430237a0efda162ec66a48'), ObjectId('6a430237a0efda162ec66a49'), ObjectId('6a430237a0efda162ec66a4a'), ObjectId('6a430237a0efda162ec66a4b'), ObjectId('6a430237a0efda162ec66a4c'), ObjectId('6a430237a0efda162ec66a4d'), ObjectId('6a430237a0efda162ec66a4e'), ObjectId('6a430237a0efda162ec66a4f'), ObjectId('6a430237a0efda162ec66a50'), ObjectId('6a430237a0efda162ec66a51'), ObjectId('6a430237a0efda162ec66a52'), ObjectId('6a430237a0efda162ec66a53'), ObjectId('6a430237a0efda162ec66a54'), ObjectId('6a430237a0efda162ec66a55'), ObjectId('6a430237a0efda162ec66a56')], acknowledged=True)

# %% [markdown]
# ## Task 2
# Write a Python program and the necessary files to create a web application. When either the route `"/reports"` or `"/"` is visited, the web application will return a HTML page to display a report table of all the lost items found in the database, under appropriate table headings, sorting the records by date in ascending order.
#
# Save your program code as
#
# ```text
# Task3_2_<name>_<index number>.py
# ```
#
# with any additional files / subfolders as needed in a folder named
#
# ```text
# Task3_2_<name>_<index number>
# ```
#
# Run the web application and save the returned reports page as
#
# ```text
# Task3_2_<name>_<index number>.html
# ```
# <div style="text-align: right">[5]</div>

# %%
# Your Answer Here

# %% [markdown]
# ## Task 3
# Implement the following functionality to allow for new lost items to be reported.
#
# Student Affairs staff will visit the `"/submit"` route to save information of new lost item to the database.
#
# Create a `"Submit Lost Item"` HTML form that allows the staff to key in details like `item_name`, `description`, `category`, `date_lost` and `location`.
#
# You should do validation of the `date_lost`, and ensure that invalid dates (for example, `'2025-02-31'` and `'2025/12/12'`) are not accepted, and notify the user that the entered date is invalid.
#
# After submitting the completed form, a new document should be created in the `reports` collection, and the user should be redirected to the `/reports` URL, which will show the new lost item reported, along with existing lost items.
#
# Save your program code as
#
# ```text
# Task3_3_<name>_<index number>.py
# ```
#
# with any additional files / subfolders as needed in a folder named
#
# ```text
# Task3_3_<name>_<index number>
# ```
#
# Run the web application, add a new report as below, and save the resultant report page as
#
# ```text
# Task3_3_<name>_<index number>.html
# ```
#
# - Item Name: `Spectacles`
# - Description: `Pink spectacles left outside the Hall`
# - Category: `Accessories`
# - Date Lost: `2025-07-31`
# - Location: `Hall`
# <div style="text-align: right">[7]</div>

# %%
# Your Answer Here

# %% [markdown]
# ## Task 4
# Implement the following functionality to allow the staff to search for lost items
# - by category, or
# - by date, or
# - by both category and date.
#
# Student Affairs staff will visit the `"/search"` route to perform a search on lost items in the database.
#
# Create a `"Search Lost Item"` HTML form that contains two form inputs, `"Category"` and `"Date Lost"`. If the staff to key in only one of the two fields, the search will only show items that fulfil the search field entered. If both fields are entered, only items that fulfil both criteria will be shown in a html table below the search form.
#
# Save your program code as
#
# ```text
# Task3_4_<name>_<index number>.py
# ```
#
# with any additional files / subfolders as needed in a folder named
#
# ```text
# Task3_4_<name>_<index number>
# ```
#
# Search for lost items on date: `'2025-07-31'` and save output as
#
# ```text
# Task3_4_1_<name>_<index number>.html
# ```
#
# Search for lost items with
# - date: `'2025-07-31'` and
# - category: `"Accessories"`
# and save the output as
#
# ```text
# Task3_4_2_<name>_<index number>.html
# ```
# <div style="text-align: right">[7]</div>

# %%
# Your Answer Here
