# %% [markdown]
# # 2025 H2 Computing JC2 Prelim Exam

# %%
## DO NOT MODIFY this cell. Run it to enter your name and class. ##

stud_name = input('Enter your full name: ')
cg = input('Enter your CG: ')

# %% [markdown]
# # Question 1

# %%
# Task 1.1

# %%
# Task 1.2

# %%
# Task 1.3

# %%
# Task 1.4

# Do not modify the following:
from secured_module import *

secured_hash_table = data()


# Write your program code below:

def query(tbl, nric):
    pass

# %%
# Task 1.5

# %% [markdown]
# # Question 2

# %%
data = [('Emma', '12-05-2004'), ('Evelyn', '12-05-2008'),
        ('Amelia', '14-02-2006'), ('Ava', '14-02-2004'),
        ('Lucas', '29-08-2003'), ('Benjamin', '19-09-2005'), 
        ('Olivia', '07-01-2003'), ('Grace', '09-12-2003'), 
        ('Ethan', '19-09-2003'), ('Michael', '07-01-2009'), 
        ('Noah', '12-05-2006'), ('James', '22-03-2003')]

# %%
# Task 2.1

# %%
# Task 2.2

# %% [markdown]
# # Question 3

# %%
#Task 3.1

# %%
#Task 3.2

# %%
#Task 3.3

# %%
#Task 3.4

# %% [markdown]
# # Question 4

# %%
# Task 4.1

# %%
# Task 4.2

# %%
# Task 4.3

# %%
# Task 4.4

# %%
# Task 4.5

# %% [markdown]
# # Question 5
#
# Follow the instructions given in the quesition paper.

# %% [markdown]
# ~ The End ~
