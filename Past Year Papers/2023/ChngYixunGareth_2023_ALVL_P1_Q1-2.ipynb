# %% [markdown]
# # Question 1
#
# **(a) (i)**
#
# There is still a transitive dependency present in the fields in the Car table. DayRate field is not fully dependent on the Primary key, which is the Registration Number, as it is dependent on the Category of the Car.
#
# **(a) (ii)**
#
# If the day rate of a category were to be changed, every entry in the Car table under that category would also have to be updated.
#
# **(b)**
#
# Car:
# Primary key: RegistrationNumber
# Foreign key: CategoryName
#
# Category:
# Primary key: CategoryName
#
# Customer:
# Primary key: DriverLicenceNumber
#
# Hire:
# Primary key: Regstration Number,DateHired
# Foreign key: Registration Number, DriverLicenceNumber
#
# **(c)**
#
# ```mermaid
# erDiagram
# Car {}
# Category {}
# Customer {}
# Hire{}
#
# Car }|--||Category :""
# Hire }|--||Car:""
# Customer ||--|{ Hire:""
# ```
# <br>
#
# **(d) (i)**
#
# Require the staff entering the driver licence on entry to visually check the customer's driver licence. Have it be required to be entered twice to reduce the chances of an error being made.
#
# **(d) (ii)**
#
# Ensure that the date entered is in the correct length for its corresponding format. Ensure that the date exist when keyed in. Conduct a range check, to ensure that the date is in the future, and is at least one day longth.
#
# **(e)**
#
# using a native aplication allows user to interact with it when they do not have any internet connection.

# %% [markdown]
# # Question 2
#
# **(a)**
#
# Since the memory is always preserved, it is garaunteed that a new piece of data can be stored, given the memory has not been fully consumed. Storing of the data will be more effecient as memory allocation has been done already.
#
# **(b)**
#
# Since the memory is dynamically allocated, the memory required will not be consumed until the data is ready to be stored, saving memory. An unlimited amount of data can be stored given an unlimited maximum memory available on the local machine.
#
# **(c)**
#
# A printer with a known maximum queue size. It will prevent any memory issues during runtime.
#
# **(d)**
#
# A binary search tree. It is more optimal to use dynamic memory allocation as the tree is dynamically generated and there is usually no maximum size to it.
#
# **(e)**
# ```python
# def find(linked_list,value,head):
#     if head == -1:
#         return -1
#     curr = head
#     while curr != -1:
#         if linked_list[curr] == value:
#             return curr
#         else:
#             curr = linked_list[curr].next
# ```
# **(f)**
# ```python
# def push(stack,value,top=top):
#     if len(stack) == 100:
#         return False
#     global top
#     top += 1
#     stack[top] = value
#     return True
# ```

# %% [markdown]
# # Question 3
#
# **(a)**
#
# **(b)**
# Attributes:
# - timer
# - alarm
# - state (on / off)
# Methods:
# - turn on
# - turn off
# - set timer
# - start timer
# - end timer
# - start alarm
# - stop alarm
#
# **(c)**
# This is to prevent external function calls or users from injecting values, that might be illegal, into the software that might result in the software failing or in extreme scenarios, the users can gain direct access to the software.
#
# **(d)**
# Polymorphism is the overiding of methods such that a subclass maybe have a method of the same name as its parent but might perform differing tasks.

# %% [markdown]
# # Question 4
#
# **(a)**
#
# The memory used for an array is contiguous while that of linked list is not as nodes are scattered across memory. The index time is O(1) for array while that of linked list is O(n) as the linked list must be traversed. Moreover, searching for elements in an array can have time complexity of possibly O(nlogn) with the use of binary search algorithm while that in linked list will be only O(n).
#
# **(b)**
#
# The first node inserted into a binary search tree is inserted as the root of the tree. Then, upon the insertion of another node, we must first compare the values in the node we want to insert to that of the root. If the node to insert has a larger data value, we insert to the right of the root, else to the left. This sequence for insertion occurs until a node hits a leaf node whereby, the final comparison determins if it will be on the left or right of the leaf node.
#
# **(c)**
#
# Depending on the insertion order and the comparison of data, the binary search trees might have different shapes. If the smallest piece of data is inserted first, the entire binary search tree will be unbalanced to the right. If the largest piece of data is inserted first, the entire binary search tree will be unbalanced to the left.
#
# **(d)(i)**
# Two operations that can be performed on a queue is to dequeue the first object in the queue given the queue is not empty, and to enqueue an object to the last position in the queue given the queue is not full.
#
# **(d)(ii)**
# The two pinters required to implement a queue is a front and rear pointer. The front pointer tracks the first item in the queue while the rear pointer can track the last item in the queue. As of which, both functions of the pointers depend on the method of implementation of the queue
#
# **(d)(iii)**
# A printer utilising a print queue to allow users to make request to the printer which places the print job into a print queue.
#
# **(d)(iv)**
# A circular queue allows the allocated fix memory of an array to be utilised infinitely many times as a circular queue circles back around and makes use of the indexes whereby items have already been dequeued. On the contrary, a linear queue only has a 1 time use as the pointers only increase in one direction.

# %% [markdown]
# # Question 5
#
# **(a)(i)**
#
# Jeffery's network application will first use a hash function to create hash total. The hash total is then encrypted using the Sender's private key to create a digital signature
#
# **(a)(ii)**
#
# Upon receiving the digitial signature, Kim uses Jeffery's public key to decrypt it. He subsequently runs the same hash function jeffery used, on the message and obtains a hash total. He then compares the decrypted hash total with the newly generated hash total, if they are identitical, the authenticity of the digital signature is confirmed.
#
# **(b)(i)**
#
# X.X.X.X where X's decimal range is between 0 to 255 inclusive
#
# **(b)(ii)**
#
# IP addresses can be either statically allocated which results in a permanently fixed IP address, or dynamicaly allocated via Dynamic Host Configuration Protcol(DHCP) which provides an IP from a pool of available IPs and recycles the IP upon the lost of connection of the device from the network.
#
# **(b)(iii)**
#
# In a packet-switching network, messages are broken down into packets which holds the message data, a sequence number and the destination IP address. The packets are then sent on the most efficient route decided by the routers and the packets makes hops from one router to another until they reach their final destination. The packets are subsequently rearraged to form back the original message utilising the sequence numbers.
#
# **(b)(iv)**
#
# A router acts as the intermediary hardware devices that receives packets, decrement the time to live of a packet and sends the packet if it's time to live is not zero.
#
# **(c)(i)**
#
# 77
#
# **(c)(ii)**
#
# 1001101
#
# **(c)(iii)**
#
# UTF-8 encoding is more universal, being a universal standard, most software's recognise the encoding format, while ASCII does not support many characters like those with accents or in other languages like chinese characters.

# %% [markdown]
# # Question 6
#
# **(a)**
#
# A quicksort algorithm finds the elements that are greater than, equal and lesser than a pivot that can be optimally chosen by random and placed into an array. The different quicksort algorithm is subsequently called on the greater than and less than array until there is only an equal array. This algorithm repeat and connects all the list together in the order: [lesser than] + [equal] + [greater than] to form a sorted list in ascending order.
#
# **(b)**
#
# $$O(n^2)$$
