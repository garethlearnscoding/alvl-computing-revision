# %% [markdown]
# # Question 4
#
# **4 (a)(i)**
#
# ```mermaid
# erDiagram
#     Agent {
#         INTEGER agent_ref_number
#         STRING agent_name
#         INTEGER salary
#     }
#
#     Customer {
#         INTEGER custom_ref_number
#         STRING customer_name
#         INTEGER mobile_phone_number
#         STRING email_address
#     }
#
#     Property {
#         INTEGER property_ref_code
#         STRING address
#         INTEGER price
#         INTEGER number_of_bedrooms
#     }
#
#     Viewing {
#         INTEGER property_ref_code
#         INTEGER customer_ref_number
#         INTEGER agent_ref_number
#         STRING date
#         STRING time
#     }
#
#     Viewing }o--|| Customer :""
#     Viewing }o--|| Agent :""
#     Property ||--o{ Viewing :""
#
# ```
# <br>

# %% [markdown]
# **4 (a)(ii)**
#
# Agent(<span style="text-decoration: underline;border-bottom: 2px dashed white;padding-bottom: 2px;">agent_ref_number</span>,agent_name,salary)
#
# Customer(<span style="text-decoration: underline;border-bottom: 2px dashed white;padding-bottom: 2px;">customer_ref_number</span>,customer_name,mobile_phone_number,email_address)
#
# Property(<span style="text-decoration: underline;border-bottom: 2px dashed white;padding-bottom: 2px;">property_ref_number</span>,address,price,number_of_bedrooms)
#
# Viewing(<span style="text-decoration: underline;">property_ref_code</span>,<span style="text-decoration: underline;">customer_ref_number</span>,<span style="text-decoration: underline;">agent_ref_number</span>,date,time)

# %% [markdown]
# **4 (a)(iii)**
#
# ```plaintext
# CREATE TABLE Property(
#     property_ref_number INTEGER PRIMARY KEY,
#     address STRING,
#     price INTEGER,
#     number_of_bedrooms INTEGER,
# )
# ```

# %% [markdown]
# **4 (b)(i)**
# Backing up data ensures that data is stored properly and frequently enough such that any loss of data can be prevented as a recent enough copy can be recovered from backups. Moreover, this combats against any corruption of data or data-wiping malware.

# %% [markdown]
# **4 (b)(ii)**
# Archiving data ensures that the use of storage on the machine hosting the database is only the necessary amount, reducing cost and improving speed on larger scales when search and indexing for data in the database.

# %% [markdown]
# # Question 5
#
# **5 (a)(i)**
#
# # Question 2
#
# **2 (a)** <br>
#
# ```mermaid
#
# graph TB
#     %% Root Node
#     N8((London))
#
#     %% Level 1
#     N8 --> N3((Beijing))
#     N8 --> N10((Paris))
#
#     %% Level 2
#     N10 --> N9((New York))
#     N10 --> N11((Rome))
#
#     %% Level 3
#     N11 --> N4((Tokyo))
# ```
# <br>

# %% [markdown]
# **5 (a)(ii)**
#
# Binary search trees only have 2 child subtrees and the left child subtree is smaller than the root while the right child subtree is larger than the root.

# %% [markdown]
# **5 (a)(iii)**
#
# freeptr is set to 7. "Madrid" is inserted into index 6 of the array. The leftpointer of the 2 element will be set to 6. leftptr of element 6 is set to -1.

# %% [markdown]
# **5 (b)**
#
# Static data structure can only store a set number of data and occupies a fixed amount of memory until it is deleted which may result in an overload of memory. The data can also not be updated and not expanded or decrease.

# %% [markdown]
# **5 (c)(i)**
#
# ```python
# def reverseInOrder(rootPtr):
#     if rootPtr:
#         reverseInOrder(rootPtr.leftptr)
#         print(bst[rootPtr])
#         reverseInOrder(rootPtr.rightptr)
# ```

# %% [markdown]
# **5 (c)(ii)**
#
# Tokyo -> Rome -> Paris -> New York -> London -> Beijing

# %% [markdown]
# # Question 6
#
# **6 (a)**
#
# The term client-server architecture refers to how a server machine binds to a given address and port, and listens for client connections. Client connects to a given address and port and is able to send and recieve data to and from the client machine. Similarly, the server machine can send and receive data to and from te client connection. Data has to be encoded into bytes for transmissions.

# %% [markdown]
# **6 (b)**
#
# A local network that devices can connect to and communicate to each other via the network.

# %% [markdown]
# **6 (c)**
#
# Networking protocols are used to ensure that data is received in the correct order so that data can be deconstructed and constructed properly. It also allows computers to identify and connect to other devices.

# %% [markdown]
# **6 (d)(i)**
#
# The digital signature allows users to authenticate if the document has been altered.

# %% [markdown]
# **6 (d)(ii)**
#
# The document is hashed to produce a digest. The digest is further encrypted by the sender's private key. Upon reeiving the document, the receiver then decrypts it by the sender's public key. The document is then rehashed by the same hash function and compared to ensure authencity.

# %% [markdown]
# **6 (e)**
#
# When Bob receives the document, he decrypts the document with Alice's public key. He then rehashes the document using the same function. He then compares the hash with the original hash to see if it is still the same. Since Eve has intercepted the document, the hash he compares he with will be different.
