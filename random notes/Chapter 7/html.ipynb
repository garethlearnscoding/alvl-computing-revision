# %%
<table>
    <tr> <!-- Table Row -->
        <th></th> <!-- Table Header: Bolded Text-->
        <th></th>
    </tr>
    <tr>
        <td></td> <!-- Table data: Normal Cell-->
        <td></td>
    </tr>
</table>

# %%
<table>
    {% for i in data %}
    <tr>
        {}
    </tr>
    {% endfor %}
</table>

# %%
{{ row[0] }}

{% for row in data %}
    {{ row[0] }}
{% endfor %}

# %%
<!-- Option 1-->
{{ dict.key }}

<!-- Option 2-->
{{ dict[key] }}

# %%
<!-- Option 2-->
{% for key in dict %}
    {{ dict.key }}
{% endfor %}

<!-- Option 1-->
{% for key,value in dict.items() %}
    {{key}},{{value}}
{% endfor %}

# %%
<ol> <!-- Ordered List-->
    <li>Row 1</li> <!-- List Item-->
        <ul> <!-- Nested Unordered List-->
            <li>Nested Row 1</li> <!-- Nested List Item-->
            <li>Nested Row 2</li>
        </ul>
    <li>Row 2</li>
</ol>

# %%
<form action="/route" method="post">
    <!-- Web Form Components-->
</form>

# %%
<form action="/submit" method="post">
    <label for="name">Name</label>
    <input id="name" name="name" type="text">

    <button type="submit">Submit</button>
</form>

# %%
<label for="o1">Option 1</label>
<input type="radio" o1" name="options" value="Option 1">
<label for="o2">Option 2</label>
<input type="radio" id="o2" name="options" value="Option 2">
<label for="o3">Option 3</label>
<input type="radio" id="o3" name="options" value="Option 3">

# %%
<label for="q1">Question 1</label>
<input type="text" id="q1" name="question1">
