# %%
from flask import Flask

app = Flask(__name__)

# %%
@app.route('/')
def index():
    return "HELLO"

# %%
@app.route('/<n>')
def some_function(n):
    return n

# %%
@app.route('/<int: n>')
def some_function(n):
    return n

# %%
<!DOCTYPE html>
<html>
    <head>
        <title>67</title>
    </head>
    <body>
        <p>Hello: IDK What to write :)</p>
    </body>
</html>

# %%
@app.route('/')
def index():
    return render_template("index.html")

# %%
<!DOCTYPE html>
<html>
    <head>
        <title>67</title>
    </head>
    <body>
        <p>This is a variable: {{variable}} </p>
    </body>
</html>

# %%
@app.route('/')
def index():
    return render_template("index.html",variable="VARIABLE")
